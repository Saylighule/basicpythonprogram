# %%
# Arithmatic operator

# %%
a=10
b=3

# %%
# addition

# %%
a+b
# Out:
# 13

# %%
# subtraction

# %%
a-b
# Out:
# 7

# %%
# multiplication

# %%
a*b
# Out:
# 30

# %%
# division

# %%
a/b
# Out:
# 3.3333333333333335

# %%
# modulas

# %%
a % b
# Out:
# 1

# %%
# floor Division

# %%
a // b
# Out:
# 3

# %%
# Comparision Operators

# %%
x = 5
y = 10

# %%
# equal to

# %%
x == y
# Out:
# False

# %%
# Not equal to

# %%
x != y
# Out:
# True

# %%
# Greater than

# %%
x > y
# Out:
# False

# %%
# less than

# %%
x < y
# Out:
# True

# %%
# Greater than or equal to

# %%
x >= y
# Out:
# False

# %%
# less than or equal to

# %%
x <= y
# Out:
# True

# %%
# Logical operator

# %%
# and: Returns true only if both conditions are true.
# not: Reverse the result, inverting true or false and vice versa.
# or: return true if at one condition are true.

# %%
a = True
b = False

# %%
# And

# %%
a and b
# Out:
# False

# %%
# OR

# %%
a or b
# Out:
# True

# %%
# not

# %%
not a
# Out:
# False

# %%
# Assignment operators

# %%
x = 5

# %%
x=x+5

# %%
print(x)
# Out:
# 10

# %%
x=x-5

# %%
print(x)
# Out:
# 5

# %%
x = x+3

# %%
x += 3

# %%
x
# Out:
# 11

# %%
x -= 2

# %%
x
# Out:
# 9

# %%
x *= 4

# %%
x
# Out:
# 36

# %%
x /= 3

# %%
x
# Out:
# 12.0

# %%
# Membership Operators

# %%
fruits =["apple","banana","mango"]

# %%
"mango"  in fruits
# Out:
# True

# %%
"Grapes" not in fruits
# Out:
# True

# %%
# Identity Operators

# %%
a=[1,2,3]
b = a
c =[1,2,3]

# %%
# True

# %%
a is b
# Out:
# True

# %%
# False

# %%
a is c
# Out:
# False

# %%
# True

# %%
a is not c
# Out:
# True

# %%
b is c
# Out:
# False

# %%
b is a
# Out:
# True

# %%
a is not b
# Out:
# False
