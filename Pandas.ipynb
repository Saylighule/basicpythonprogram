# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pandas

# %%
#install pandas

# %%
import pandas as pd

# %%
s =pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
dic={
    "name":"sayali",
    "age":"17",
    "marks":71.77
}

# %%
print(dic)
# Out:
# {'name': 'sayali', 'age': '17', 'marks': 71.77}

# %%
s=pd.Series(dic)

# %%
s
# Out:
# name     sayali
# age          17
# marks     71.77
# dtype: object

# %%
pd.Series(5,index=['0','1','2','3','4'])
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
s1=pd.Series([10,20,30],index=['a','b','c'])

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1.values
# Out:
# array([10, 20, 30])

# %%
s1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
s1.shape
# Out:
# (3,)

# %%
s1*2
# Out:
# a    20
# b    40
# c    60
# dtype: int64

# %%
s1=pd.Series([10,None,30])

# %%
s1
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# dtype: float64

# %%
s1.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s1.dropna()
# Out:
# 0    10.0
# 2    30.0
# dtype: float64

# %%
s1.fillna(5)
# Out:
# 0    10.0
# 1     5.0
# 2    30.0
# dtype: float64

# %%
s=pd.Series([1,2,2,3,3,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
s=pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
#dataframe create

# %%
Data ={
    "Roll_N0":[100,200,300,400],
    "name":["Sayali","Tanishka","pallavi","Bhaguu"],
    "marks":[99,101,100,98]
}

# %%
Data
# Out:
# {'Roll_N0': [100, 200, 300, 400],
#  'name': ['Sayali', 'Tanishka', 'pallavi', 'Bhaguu'],
#  'marks': [99, 101, 100, 98]}

# %%
df=pd.DataFrame(Data)

# %%
df
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali     99
# 1      200  Tanishka    101
# 2      300   pallavi    100
# 3      400    Bhaguu     98

# %%
Data ={
    "Subject":["java","python","OOP"],
    "Marks":[99,98,97,95],
    "Grade":['A','B','C']
}

# %%
Data
# Out:
# {'Subject': ['java', 'python', 'OOP'],
#  'Marks': [99, 98, 97, 95],
#  'Grade': ['A', 'B', 'C']}

# %%
df.to_csv('marks_data.csv',index=False)

# %%
df = pd.read_csv("marks_data.csv")

# %%
df
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali     99
# 1      200  Tanishka    101
# 2      300   pallavi    100
# 3      400    Bhaguu     98

# %%
df.head()
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali     99
# 1      200  Tanishka    101
# 2      300   pallavi    100
# 3      400    Bhaguu     98

# %%
df.tail()
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali     99
# 1      200  Tanishka    101
# 2      300   pallavi    100
# 3      400    Bhaguu     98

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Roll_N0', 'name', 'marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_N0  4 non-null      int64
#  1   name     4 non-null      object
#  2   marks    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#           Roll_N0       marks
# count    4.000000    4.000000
# mean   250.000000   99.500000
# std    129.099445    1.290994
# min    100.000000   98.000000
# 25%    175.000000   98.750000
# 50%    250.000000   99.500000
# 75%    325.000000  100.250000
# max    400.000000  101.000000

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of    Roll_N0   name  marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False>

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali     99
# 1      200  Tanishka    101
# 2      300   pallavi    100
# 3      400    Bhaguu     98

# %%
df['marks']=df['marks'].astype(float)

# %%
df
# Out:
#    Roll_N0      name  marks
# 0      100    Sayali   99.0
# 1      200  Tanishka  101.0
# 2      300   pallavi  100.0
# 3      400    Bhaguu   98.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_N0  4 non-null      int64
#  1   name     4 non-null      object
#  2   marks    4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df["marks"]
# Out:
# 0     99.0
# 1    101.0
# 2    100.0
# 3     98.0
# Name: marks, dtype: float64

# %%
df["name"]
# Out:
# 0      Sayali
# 1    Tanishka
# 2     pallavi
# 3      Bhaguu
# Name: name, dtype: object

# %%
df[["name","marks"]]
# Out:
#        name  marks
# 0    Sayali   99.0
# 1  Tanishka  101.0
# 2   pallavi  100.0
# 3    Bhaguu   98.0

# %%
df=df.sort_values(by="marks",ascending=False)

# %%
df
# Out:
#    Roll_N0      name  marks
# 1      200  Tanishka  101.0
# 2      300   pallavi  100.0
# 0      100    Sayali   99.0
# 3      400    Bhaguu   98.0
