# %%
# Data structure

# %%
# Data structures are used to store and organize data so it can be

# %%
# List
# A list can be ordered, mutable change collection of items

# %%
nums = [10,20,30,40]
type(nums)
# Out:
# list

# %%
# Tuple

# %%
# A tuple is an ordered, immutable (not changable) collection

# %%
t = (10,20,30)
type(t)
# Out:
# tuple

# %%
# Set

# %%
# A set is an unordered collection of unique elements

# %%
s = {1,2,3,3,4}
type(s)
# Out:
# set

# %%
# Dictionary

# %%
# A dictionary stores data in key value pairs

# %%
student = {
    "name":"Rahul",
    "age":25
}
type (student)
# Out:
# dict

# %%
fruits =["Apple,Mango,Grapes,Banana"]
print(fruits)
# Out:
# ['Apple,Mango,Grapes,Banana']

# %%
type(fruits)
# Out:
# list

# %%
Student = {
    "name":"Sayali",
    "age":18,
    "sub":"python",
    "class":"TYIF"
        }
print(Student)
# Out:
# {'name': 'Sayali', 'age': 18, 'sub': 'python', 'class': 'TYIF'}

# %%
type(Student)
# Out:
# dict

# %%
num =[12,13,18,19]
print(num)
# Out:
# [12, 13, 18, 19]

# %%
type(num)
# Out:
# list

# %%
num =[]

# %% [raw]
# print(num)

# %%
# String list

# %%
fruits = ["apple","mango","banana"]

# %%
type(fruits)
# Out:
# list

# %%
# mixed list

# %%
mixed = [1,"python",3.5,True]

# %%
mixed
# Out:
# [1, 'python', 3.5, True]

# %%
type(mixed)
# Out:
# list

# %%
# Accessing Elements

# %%
fruits = ["apple","banana","mango"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-1]
# Out:
# 'mango'

# %%
# list Slicing

# %%
nums = [10,20,30,40,50]

# %%
# Elements from index 1 to 3

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
# from beginning to index 2

# %%
nums[:3]
# Out:
# [10, 20, 30]

# %%
# from index 2 to end

# %%
nums[2:]
# Out:
# [30, 40, 50]

# %%
# Modyfying List Elements

# %%
colors = ["red","blue","green"]

# %%
# changing elements

# %%
colors[1] ="yellow"

# %%
colors
# Out:
# ['red', 'yellow', 'green']

# %%
fruits =["apple","mango","grapes"]

# %%
# changing elements

# %%
fruits[2] ="Guava"

# %%
fruits
# Out:
# ['apple', 'mango', 'Guava']

# %%
# Adding elements

# %%
nums = [1,2,3]

# %%
# Adding single element at end

# %%
nums.append(4)

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
# Adding element at specific position

# %%
nums.insert(1, 100)

# %%
nums
# Out:
# [1, 100, 2, 3, 4]

# %%
# Adding multiple elements

# %%
nums.extend([5,60])

# %%
nums
# Out:
# [1, 100, 2, 3, 4, 5, 60]

# %%
# Removing Elements

# %%
fruits = ["apple","banana","mango"]

# %%
fruits.remove("banana")

# %%
fruits
# Out:
# ['apple', 'mango']

# %%
fruits.pop()
# Out:
# 'mango'

# %%
del nums[4]

# %%
nums
# Out:
# [1, 100, 2, 3, 5, 60]

# %%
nums.clear()

# %%
nums
# Out:
# []

# %%
# length of list

# %%
num1 =[1,2,3,4,5,6]

# %%
len(num1)
# Out:
# 6

# %%
# sorting lists

# %%
nums = [4,1,3,2]

# %%
# sort ascending

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
# sort descending

# %%
nums.sort(reverse=True)

# %%
nums
# Out:
# [4, 3, 2, 1]

# %%
# Reversing list

# %%
nums = [1,2,3]

# %%
# Reverse the list

# %%
num.reverse()

# %%
nums
# Out:
# [1, 2, 3]

# %%
# Copying Lists

# %%
a = [1,2,3]

# %%
# Copying list

# %%
b = a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
# joining lists

# %%
a=[1,2,3]
b=[4,5,6]

# %%
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a+b*4
# Out:
# [1, 2, 3, 4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6]

# %%
a+a
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a=[1,2,3,4,5,6,7,5,5,5,8,9,10]

# %%
max(a)
# Out:
# 10

# %%
min(a)
# Out:
# 1

# %%
sum(a)
# Out:
# 55

# %%
a.count(5)
# Out:
# 1

# %%
a.count(5)
# Out:
# 4

# %%
a.index(3)
# Out:
# 2

# %%
# creating a tuple

# %%
a=()

# %%
a
# Out:
# ()

# %%
num=(2,3,4)

# %%
print(num)
# Out:
# (2, 3, 4)

# %%
p=("sayali","tanishka","pallavi","bhaguu")

# %%
p
# Out:
# ('sayali', 'tanishka', 'pallavi', 'bhaguu')

# %%
s1=("sayali",3.14,11,True)

# %%
print(s1)
# Out:
# ('sayali', 3.14, 11, True)

# %%
s1[2]
# Out:
# 11

# %%
s1[-1]
# Out:
# True

# %%
s1[-2]
# Out:
# 11

# %%
s1[3]
# Out:
# True

# %%
p[0:3]
# Out:
# ('sayali', 'tanishka', 'pallavi')

# %%
p[:3]
# Out:
# ('sayali', 'tanishka', 'pallavi')

# %%
len(s1)
# Out:
# 2

# %%
5 in s1
# Out:
# False

# %%
t=(2)

# %%
t
# Out:
# 2

# %%
for s1 in (s1):
    print(s1)
# Out:
# 0
# 3

# %%
s2 = (1,2)

# %%
s3 =(3,4)

# %%
s2+s3
# Out:
# (1, 2, 3, 4)

# %%
s2*2+s3*2
# Out:
# (1, 2, 1, 2, 3, 4, 3, 4)

# %%
touple =(7,6,5,4)

# %%
touple
# Out:
# (7, 6, 5, 4)

# %%
max(touple)
# Out:
# 7

# %%
min(touple)
# Out:
# 4

# %%
sum(touple)
# Out:
# 22

# %%
list(s2)
# Out:
# [1, 2]

# %%
# list

# %%
list =[1,2,3,4]

# %%
list
# Out:
# [1, 2, 3, 4]

# %%
tuple[list]
# Out:
# tuple[[1, 2, 3, 4]]

# %%
tuple(list)
# Out:
# (1, 2, 3, 4)

# %%
# single element tuple

# %%
single = (10,)

# %%
single
# Out:
# (10,)

# %%
# tuple slicing

# %%
nums = (10,20,30,40,50)

# %%
# Elements from index 1 to 3

# %%
nums [1:4]
# Out:
# (20, 30, 40)

# %%
# from begining to index 2

# %%
nums[:3]
# Out:
# (10, 20, 30)

# %%
# from index 2 to end

# %%
nums [2:]
# Out:
# (30, 40, 50)

# %%
# tuple unpacking

# %%
nums = (1,2,3)

# %%
# unpacking values

# %%
a,b,c= nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
v =("welcome to python")

# %%
v
# Out:
# 'welcome to python'

# %%
v.upper()
# Out:
# 'WELCOME TO PYTHON'

# %% [markdown]
# v.lower()

# %%
v.lower()
# Out:
# 'welcome to python'

# %%
len(v)
# Out:
# 17

# %%
v =("welcome \n to \n python")

# %%
v
# Out:
# 'welcome \n to \n python'

# %%
v
# Out:
# 'welcome \n to \n python'

# %%
print("welcome \n to \n python \n programming \n")
# Out:
# welcome
#  to
#  python
#  programming

# %%
# set

# %%
s1 ={12,34,6,7,8,4}

# %%
s1
# Out:
# {4, 6, 7, 8, 12, 34}

# %%
type (s1)
# Out:
# set

# %%
# empty set

# %%
s2 ={}

# %%
s2
# Out:
# {}

# %%
s3 ={1,2,3,4,1,2,1,1,1,1}

# %%
s3
# Out:
# {1, 2, 3, 4}

# %%
# add element in set

# %%
s3.add(8)

# %%
s3
# Out:
# {1, 2, 3, 4, 8}

# %%
# add multiple element in set

# %%
s3.update([34,65,75,23,12])

# %%
s3
# Out:
# {1, 2, 3, 4, 8, 12, 23, 34, 65, 75}

# %%
# remove element in set

# %%
s3.remove(65)

# %%
s3
# Out:
# {1, 2, 3, 4, 8, 12, 23, 34, 75}

# %%
# remove element using pop

# %%
s3.pop()
# Out:
# 1

# %%
s3.pop()
# Out:
# 2

# %%
s3.discard(23)

# %%
# clear method used to clear all elements in lists

# %%
s3.clear()

# %%
s3
# Out:
# set()

# %%
s4={12,67,45,56,13}

# %%
s4
# Out:
# {12, 13, 45, 56, 67}

# %%
len(s4)
# Out:
# 5

# %%
99 in s4
# Out:
# False

# %%
for  s4 in(s4):
    print(s4)
# Out:
# 13
# 67
# 56
# 12
# 45

# %%
s5={1,13.5,"string",True}

# %%
s5
# Out:
# {1, 13.5, 'string'}

# %%
s6={3,13.5,"String",True}

# %%
s6
# Out:
# {13.5, 3, 'String', True}

# %%
a={1,2}
b={3,4}

# %%
a
# Out:
# {1, 2}

# %%
b
# Out:
# {3, 4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a1={1,2,3}
b1={2,3,4}

# %%
a1-b1
# Out:
# {1}

# %%
a1.difference(b1)
# Out:
# {1}

# %%
a1.symmetric_difference(b1)
# Out:
# {1, 4}

# %%
nums={12,23,54,76}

# %%
max(nums)
# Out:
# 76

# %%
min(nums)
# Out:
# 12

# %%
sum(nums)
# Out:
# 165

# %%
nums =[1,2,3,4,5]

# %%
set(nums)
# Out:
# {1, 2, 3, 4, 5}

# %%
nums =[1,2,3]

# %%
set(nums)
# Out:
# {1, 2, 3}
