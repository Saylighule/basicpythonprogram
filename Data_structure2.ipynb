# %%
nums =[1,2,3,4]

# %%
set(nums)
# Out:
# {1, 2, 3, 4}

# %%
a ={1,2,3}
b={2,3,4}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
# using &

# %%
a & b
# Out:
# {2, 3}

# %%
a ={1,2,3}

# %%
# copying set

# %%
b=a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
b =a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
# nested sets using frozenset()
# normal set cannot contains sets
# use frozen sets for nested set

# %%
a = frozenset ({1,2})

# %%
b ={a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
type(b)
# Out:
# set

# %%
type(a)
# Out:
# frozenset

# %%
x=frozenset({1,2})

# %%
y={x,3,4}

# %%
y
# Out:
# {3, 4, frozenset({1, 2})}

# %%
# dictionary

# %%
# creating dictionary

# %%
student = {
    "name":"pallavi",
    "age":18,
    "class":"syit"
}

# %%
type(student)
# Out:
# dict

# %%
print(student)
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit'}

# %%
flowers ={
    "red":"rose",
    "yellow":"sunflower",
    "green":"lotus"
}

# %%
print(flowers)
# Out:
# {'red': 'rose', 'yellow': 'sunflower', 'green': 'lotus'}

# %%
fruits ={
    "red":"apple",
    "orange":"orange",
    "green":"watermelon"
}

# %%
fruits
# Out:
# {'red': 'apple', 'orange': 'orange', 'green': 'watermelon'}

# %%
dic = {
    1:"pallavi",
    2:"tanishka",
    3:"sayali",
    4:"Bhaguu"
}

# %%
dic
# Out:
# {1: 'pallavi', 2: 'tanishka', 3: 'sayali', 4: 'Bhaguu'}

# %%
# mixed datatype

# %%
mixed={
    1:"one",
    "name":"sayali",
    True:100
}

# %%
mixed
# Out:
# {1: 100, 'name': 'sayali'}

# %%
m ={
    3:"one",
    "name":"pallavi",
    True:100
}

# %%
m
# Out:
# {3: 'one', 'name': 'pallavi', True: 100}

# %%
# accesing using key

# %%
student=["name"]

# %%
'sayali'
# Out:
# 'sayali'

# %%
student=["age"]

# %%
18
# Out:
# 18

# %%
# accessing using get

# %%
# adding elements
# add new key value pair

# %%
student ={
    "name":"sayali"
}

# %%
student["age"]=21

# %%
student
# Out:
# {'name': 'sayali', 'age': 21}

# %%
# add another value

# %%
student["std"]="TYIF"

# %%
student
# Out:
# {'name': 'sayali', 'age': 21, 'std': 'TYIF'}

# %%
# modify

# %%
student["name"]="sayali"

# %%
student
# Out:
# {'name': 'sayali', 'age': 21, 'std': 'TYIF'}

# %%
# remove

# %%
student.pop("name")
# Out:
# 'sayali'

# %%
student
# Out:
# {'age': 21, 'std': 'TYIF'}

# %%
# remove last inserted item

# %%
student.popitem()
# Out:
# ('std', 'TYIF')

# %%
student
# Out:
# {'age': 21}

# %%
# delete

# %%
del student["age"]

# %%
student
# Out:
# {}

# %%
# new dic

# %%
emp={
    "name":"omkar",
    "empid":101,
    "age":18,
    "salary":25000
}

# %%
len(emp)
# Out:
# 4

# %%
# checking key

# %%
"std" in emp
# Out:
# False

# %%
# loop through key

# %%
for key in emp:
    key
    print(key)
# Out:
# name
# empid
# age
# salary

# %%
for value in emp.values():
    value
    print(value)
# Out:
# omkar
# 101
# 18
# 25000

# %%
# both key and values

# %%
for items in emp.items():
    items
    print(items)
# Out:
# ('name', 'omkar')
# ('empid', 101)
# ('age', 18)
# ('salary', 25000)

# %%
emp.keys()
# Out:
# dict_keys(['name', 'empid', 'age', 'salary'])

# %%
emp.values()
# Out:
# dict_values(['omkar', 101, 18, 25000])

# %%
emp.items()
# Out:
# dict_items([('name', 'omkar'), ('empid', 101), ('age', 18), ('salary', 25000)])

# %%
#copy dic

# %%
s=emp.copy()

# %%
s
# Out:
# {'name': 'omkar', 'empid': 101, 'age': 18, 'salary': 25000}

# %%
#nested

# %%
students={
    "stu2":
    "name
    "stu1":{
        "name":"rahul",
        "age":22
    }
}

# %%
students
# Out:
# {'stu1': {'name': 'rahul', 'age': 22}}

# %%
# access nested values

# %%
students["stu1"]["name"]
# Out:
# 'rahul'

# %%
student={
    "name":"sayali",
    "age":21,
    "course":"python programming"
}

# %%
type(student)
# Out:
# dict

# %%
print(student)
# Out:
# {'name': 'sayali', 'age': 21, 'course': 'python programming'}

# %%
for key in student:
    key
    print(key)
# Out:
# name
# age
# course

# %%
for value in student.values():
    value
    print(value)
# Out:
# sayali
# 21
# python programming

# %%
# delete

# %%
del student["age"]

# %%
student
# Out:
# {'name': 'sayali', 'course': 'python programming'}
