# %%
#variables

# %%
# A variable is a used to store data

# %%
student_name="Sayali"

# %%
print(student_name)
# Out:
# Sayali

# %%
student_age=21

# %%
print(student_age)
# Out:
# 21

# %%
student_marks=88.5

# %%
print(student_marks)
# Out:
# 88.5

# %%
# printing with Lables

# %%
name="sayali"

# %%
print("Name:",name)
# Out:
# Name: sayali

# %%
age=21

# %%
print("Age:",age)
# Out:
# Age: 21

# %%
city="Mumbai"

# %%
print("city:",city)
# Out:
# city: Mumbai

# %%
# Changing Variables Values

# %%
course="python"

# %%
print("before changing:",course)
# Out:
# before changing: python

# %%
course="data science"

# %%
after changing:
# Out:
#   Cell In[22], line 1
#     after changing:java
#           ^
# SyntaxError: invalid syntax

# %%
x,y,z=100,200,300

# %%
print("y=",y)
# Out:
# y= 200

# %%
print("z=",z)
# Out:
# z= 300

# %%
# same value to Multiple variables

# %%
maths=science=english=90

# %%
print("maths:",maths)
# Out:
# maths: 90

# %%
print("science:",science)
# Out:
# science: 90

# %%
print("english:",english)
# Out:
# english: 90

# %%
# Invalid Variables Names

# %%
2name="Rahul"
# Out:
#   Cell In[32], line 1
#     2name="Rahul"
#     ^
# SyntaxError: invalid decimal literal

# %%
student-name="amit"
# Out:
#   Cell In[33], line 1
#     student-name="amit"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name="Rahul T"
# Out:
#   Cell In[34], line 1
#     full name="Rahul T"
#          ^
# SyntaxError: invalid syntax

# %%
class ="python"
# Out:
#   Cell In[35], line 1
#     class ="python"
#           ^
# SyntaxError: invalid syntax

# %%
# dynamic typing

# %%
# python automatically understands the data type

# %%
value = 100

# %%
print(value)
# Out:
# 100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value = "python"

# %%
print(value)
# Out:
# python

# %%
print (type(value))
# Out:
# <class 'str'>

# %%
value =45.75

# %%
print(value)
# Out:
# 45.75

# %%
# Input Example

# %%
name = input("Enter your name:")
# Out:
# Enter your name: Tanu

# %%
print("name:",name)
# Out:
# name: Tanu

# %% [raw]
# age = input("Enter your age")

# %%
print("age:",age)
# Out:
# age: 25

# %%
# input() always gives output in string format

# %%
age = input("enter age:")
print(type(age))
# Out:
# enter age: 10
# <class 'str'>

# %%
# Number Input

# %%
age = int(input("Enter age:"))
print (age)
# Out:
# Enter age: 10
# 10

# %%
year=Int(input("Enter your year))
               if(year %4==0 or year is %400==0:
                  print("year is leap:")
                  else:
               print("year is not leap:")
# Out:
#   Cell In[10], line 1
#     year=Int(input("Enter your year))
#                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
year=int(input("Enter your year:"))
if year%4==0 or year%400==0:
    print("year is leap:")
else:
    print("year is not leap:")
# Out:
# Enter your year: 2026
# year is not leap:

# %%
year=int(input("Enter your year:"))
if year %4==0 or year%400==0:
    print("year is leap:")
else:                       
    print("year is not leap:")
# Out:
# Enter your year: 2016
# year is leap:

# %%
Number=16

# %%
number=int(input("Enter your number:"))
if number >0:
    print("positive")
elif number >0:
    print ("negative")
 else number >0:
    print ("Zero")
# Out:
#   File <string>:6
#     else number >0:
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
# common escape characters

# %%
print("I like python programming:")
# Out:
# I like python programming:

# %%
# Escape characters are special symbols (starting with\) used to add formatting

# %%
# new line ->\n
# moves text to the    next time

# %%
print("Hello\n world")
# Out:
# Hello
#  world

# %%
# tab space ->\t
# adds horizontal space(tab)

# %%
print("Hello\World")
# Out:
# Hello\World

# %%
# Backlash ->\\

# %%
print("C:\\Users\\Rahul")
# Out:
# C:\Users\Rahul

# %%
# single quotes->\
# used when string is inside single quotes

# %%
print('It\'s python')
# Out:
# It's python

# %%
# Double quotes ->\"
# used when string is inside double  quotes

# %%
print("He said\"Hello\"")
# Out:
# He said"Hello"

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
