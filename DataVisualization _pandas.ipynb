# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
df =pd.DataFrame({
    "A":[50,60,70,80],
    "B":[40,55,65,75],
    "C":[30,45,55,65],
    "D":[20,35,45,55]
},index=["Q1","Q2","Q3","Q4"])

# %%
df
# Out:
#      A   B   C   D
# Q1  50  40  30  20
# Q2  60  55  45  35
# Q3  70  65  55  45
# Q4  80  75  65  55

# %%
df.shape
# Out:
# (4, 4)

# %%
df.isnull()
# Out:
#         A      B      C      D
# Q1  False  False  False  False
# Q2  False  False  False  False
# Q3  False  False  False  False
# Q4  False  False  False  False

# %%
print(df["A"])
# Out:
# Q1    50
# Q2    60
# Q3    70
# Q4    80
# Name: A, dtype: int64

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.scatter(x="A",y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df["A"].plot.pie()
# Out:
# <Axes: ylabel='A'>

# %%
df=pd.DataFrame({
    "p1":["10000","23000","34000","12000"],
    "p2":["22000","32000","6700","8000"],
    "p3":["5600","7600","4500","4350"],
    "p4":["8900","4700","8600","5400"]
},index=["W1","W2","W3","W4"])

# %%
df
# Out:
#        p1     p2    p3    p4
# W1  10000  22000  5600  8900
# W2  23000  32000  7600  4700
# W3  34000   6700  4500  8600
# W4  12000   8000  4350  5400
