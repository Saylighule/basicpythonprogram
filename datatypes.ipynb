# %%
# integer

# %%
# Integer means whole number

# %%
age=21

# %%
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
marks = 90

# %%
print(marks,type(marks))
# Out:
# 90 <class 'int'>

# %%
temperature = -5

# %%
print(temperature,type(temperature))
# Out:
# -5 <class 'int'>

# %%
# Integer operations

# %%
a=25
b=10

# %%
# addition

# %%
a + b
# Out:
# 35

# %%
# Subtraction

# %%
a - b
# Out:
# 15

# %%
# Multiplication

# %%
a * b
# Out:
# 250

# %%
# Division

# %%
a / b
# Out:
# 2.5

# %%
# floor division

# %%
a//b
# Out:
# 2

# %%
#reminder

# %%
a % b
# Out:
# 5

# %%
#power

# %%
a**b
# Out:
# 95367431640625

# %%
# string

# %%
# string means text

# %%
first_name="rahul"
last_name="temkar"
course="python programming"

# %%
print("first name:",type(first_name))
# Out:
# first name: <class 'str'>

# %%
print("first name:",type(first_name))
# Out:
# first name: <class 'str'>

# %%
print("last name:",type(last_name))
# Out:
# last name: <class 'str'>

# %%
print("course:",type(course))
# Out:
# course: <class 'str'>

# %%
# string concatenation

# %%
first_name+""+last_name
# Out:
# 'rahultemkar'

# %%
# string repition

# %%
word ="python "

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
word ="python "

# %%
print(word*3)
# Out:
# python python python

# %%
# string Indexing

# %%
language ="Python"

# %%
language ="python"

# %%
language[0]
# Out:
# 'p'

# %%
language[1]
# Out:
# 'y'

# %%
language[-1]
# Out:
# 'n'

# %%
language[-5]
# Out:
# 'y'

# %%
#string slicing

# %%
language="python programming"

# %%
language[0:7]
# Out:
# 'python '

# %%
language[7:18]
# Out:
# 'programming'

# %%
language[:5]
# Out:
# 'pytho'

# %%
language[8:]
# Out:
# 'rogramming'

# %%
language[6:]
# Out:
# ' programming'

# %%
# string methods

# %%
message = "welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
# replace
# used to replace a word or character in a string

# %%
text="I like java"

# %%
new_text=text.replace("java","python")

# %%
print(new_text)
# Out:
# I like python

# %%
text="I like python"

# %%
new_text=text.replace("python","sayali")

# %%
print(new_text)
# Out:
# I like sayali

# %%
# split 
# used to split a string into A list.

# %%
text = "apple banana mango"

# %%
words = text.split()

# %%
print(words)
# Out:
# ['apple', 'banana', 'mango']

# %%
# join
# used to join list items into a single strings

# %%
words = ['python','is','easy']

# %%
sentence ="".join(words)

# %%
print(sentence)
# Out:
# pythoniseasy

# %%
words = [ 'pallavi','are','mental']

# %%
sentence=" ".join (words)

# %%
print (sentence)
# Out:
# pallavi are mental

# %%
# strip

# %%
# used to remove extra space from the beggining and end of string.

# %%
text ="  python "

# %%
clean_text.strip()

# %%
text ="  python  "

# %%
clean_text= text.strip()

# %%
clean_text
# Out:
# 'python'

# %%
text="  pallavi  "

# %%
# lstrip remove left space

# %%
text = "   hello"

# %%
text.lstrip()
# Out:
# 'hello'

# %%
# rstrip remove right spaces

# %%
text ="hello  "

# %%
text.rstrip()
# Out:
# 'hello'

# %%
text="hii  "

# %%
text.rstrip()
# Out:
# 'hii'

# %%
# String formating

# %%
# f-strings A modern and easy way to insert variables into strings.

# %%
name ="Sayali"
age =18

# %%
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Sayali and I am 18 years old.

# %%
fruit ="apple"
fruit2 ="mango"

# %%
# Mathmatical operation inside f-string

# %%
a=10
b=5

# %%
print(f"sum={a+b}")
# Out:
# sum=15

# %%
a=25
b=8

# %% [raw]
# print (f"mul={a*b}")

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# Boolean

# %%
# Boolean has only two values:true and false

# %%
is_student = True
is_employed = False

# %%
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_employed,type(is_employed))
# Out:
# False <class 'bool'>

# %%
# Boolean with Comparisons

# %%
is_student = True
is_employee = False

# %%
print(is_student,type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_student,type(is_employee))
# Out:
# True <class 'bool'>
